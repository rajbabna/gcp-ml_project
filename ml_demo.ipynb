# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# absl-py                                  2.0.0
# aiohttp                                  3.8.6
# aiohttp-cors                             0.7.0
# aiorwlock                                1.3.0
# aiosignal                                1.3.1
# anyio                                    3.7.1
# archspec                                 0.2.2
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asttokens                                2.4.1
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.1.0
# Babel                                    2.13.1
# backoff                                  2.2.1
# backports.functools-lru-cache            1.6.5
# beautifulsoup4                           4.12.2
# bleach                                   6.1.0
# blessed                                  1.20.0
# boltons                                  23.0.0
# bq-stats                                 1.0
# Brotli                                   1.1.0
# cached-property                          1.5.2
# cachetools                               5.3.2
# certifi                                  2023.7.22
# cffi                                     1.16.0
# charset-normalizer                       3.3.2
# click                                    8.1.7
# cloud-tpu-client                         0.10
# cloudpickle                              3.0.0
# colorama                                 0.4.6
# colorful                                 0.5.5
# comm                                     0.1.4
# conda                                    23.10.0
# conda-libmamba-solver                    23.11.0
# conda-package-handling                   2.2.0
# conda_package_streaming                  0.9.0
# contourpy                                1.2.0
# cryptography                             41.0.5
# cycler                                   0.12.1
# dacite                                   1.8.1
# db-dtypes                                1.1.1
# debugpy                                  1.8.0
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# distlib                                  0.3.7
# dm-tree                                  0.1.8
# docker                                   6.1.3
# docstring-parser                         0.15
# entrypoints                              0.4
# exceptiongroup                           1.1.3
# executing                                2.0.1
# Farama-Notifications                     0.0.4
# fastapi                                  0.104.1
# fastjsonschema                           2.18.1
# filelock                                 3.13.1
# fonttools                                4.44.0
# fqdn                                     1.5.1
# frozenlist                               1.4.0
# fsspec                                   2023.10.0
# gcsfs                                    2023.10.0
# gitdb                                    4.0.11
# GitPython                                3.1.40
# google-api-core                          1.34.0
# google-api-python-client                 1.8.0
# google-auth                              2.23.4
# google-auth-httplib2                     0.1.1
# google-auth-oauthlib                     1.1.0
# google-cloud-aiplatform                  1.36.1
# google-cloud-artifact-registry           1.9.0
# google-cloud-bigquery                    3.13.0
# google-cloud-bigquery-storage            2.22.0
# google-cloud-core                        2.3.3
# google-cloud-datastore                   1.15.5
# google-cloud-language                    2.11.1
# google-cloud-monitoring                  2.16.0
# google-cloud-resource-manager            1.10.4
# google-cloud-storage                     2.13.0
# google-crc32c                            1.5.0
# google-resumable-media                   2.6.0
# googleapis-common-protos                 1.61.0
# gpustat                                  1.0.0
# greenlet                                 3.0.1
# grpc-google-iam-v1                       0.12.6
# grpcio                                   1.59.2
# grpcio-status                            1.48.2
# gymnasium                                0.28.1
# h11                                      0.14.0
# htmlmin                                  0.1.12
# httplib2                                 0.22.0
# httptools                                0.6.1
# idna                                     3.4
# ImageHash                                4.3.1
# imageio                                  2.32.0
# importlib-metadata                       6.8.0
# importlib-resources                      6.1.1
# ipykernel                                6.26.0
# ipython                                  8.17.2
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipywidgets                               8.1.1
# isoduration                              20.11.0
# jaraco.classes                           3.3.0
# jax-jumpy                                1.0.0
# jedi                                     0.19.1
# jeepney                                  0.8.0
# Jinja2                                   3.1.2
# joblib                                   1.3.2
# json5                                    0.9.14
# jsonpatch                                1.33
# jsonpointer                              2.4
# jsonschema                               4.19.2
# jsonschema-specifications                2023.7.1
# jupyter_client                           7.4.9
# jupyter_core                             5.5.0
# jupyter-events                           0.9.0
# jupyter-lsp                              2.2.0
# jupyter-server                           1.24.0
# jupyter-server-mathjax                   0.2.6
# jupyter_server_terminals                 0.4.4
# jupyterlab                               3.4.8
# jupyterlab-pygments                      0.2.2
# jupyterlab_server                        2.25.0
# jupyterlab-widgets                       3.0.9
# keyring                                  24.2.0
# keyrings.google-artifactregistry-auth    1.1.2
# kfp                                      2.4.0
# kfp-pipeline-spec                        0.2.2
# kfp-server-api                           2.0.3
# kiwisolver                               1.4.5
# kubernetes                               26.1.0
# lazy_loader                              0.3
# libmambapy                               1.5.3
# llvmlite                                 0.41.1
# lz4                                      4.3.2
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.3
# matplotlib                               3.7.3
# matplotlib-inline                        0.1.6
# mdurl                                    0.1.2
# mistune                                  3.0.2
# more-itertools                           10.1.0
# msgpack                                  1.0.7
# multidict                                6.0.4
# multimethod                              1.10
# nb-conda                                 2.2.1
# nb-conda-kernels                         2.3.1
# nbclassic                                1.0.0
# nbclient                                 0.8.0
# nbconvert                                7.11.0
# nbdime                                   3.2.0
# nbformat                                 5.9.2
# nest-asyncio                             1.5.8
# networkx                                 3.2.1
# notebook                                 6.5.6
# notebook_shim                            0.2.3
# numba                                    0.58.1
# numpy                                    1.25.2
# nvidia-ml-py                             11.495.46
# oauth2client                             4.1.3
# oauthlib                                 3.2.2
# opencensus                               0.11.3
# opencensus-context                       0.1.3
# opentelemetry-api                        1.21.0
# opentelemetry-exporter-otlp              1.21.0
# opentelemetry-exporter-otlp-proto-common 1.21.0
# opentelemetry-exporter-otlp-proto-grpc   1.21.0
# opentelemetry-exporter-otlp-proto-http   1.21.0
# opentelemetry-proto                      1.21.0
# opentelemetry-sdk                        1.21.0
# opentelemetry-semantic-conventions       0.42b0
# overrides                                7.4.0
# packaging                                23.2
# pandas                                   2.0.3
# pandas-profiling                         3.6.6
# pandocfilters                            1.5.0
# parso                                    0.8.3
# patsy                                    0.5.3
# pexpect                                  4.8.0
# phik                                     0.12.3
# pickleshare                              0.7.5
# Pillow                                   10.0.1
# pip                                      23.3.1
# pkgutil_resolve_name                     1.3.10
# platformdirs                             3.11.0
# plotly                                   5.18.0
# pluggy                                   1.3.0
# prettytable                              3.9.0
# prometheus-client                        0.18.0
# prompt-toolkit                           3.0.39
# proto-plus                               1.22.3
# protobuf                                 3.20.3
# psutil                                   5.9.3
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py-spy                                   0.3.14
# pyarrow                                  14.0.0
# pyasn1                                   0.5.0
# pyasn1-modules                           0.3.0
# pycosat                                  0.6.6
# pycparser                                2.21
# pydantic                                 1.10.13
# Pygments                                 2.16.1
# pyparsing                                3.1.1
# PySocks                                  1.7.1
# python-dateutil                          2.8.2
# python-dotenv                            1.0.0
# python-json-logger                       2.0.7
# pytz                                     2023.3.post1
# PyWavelets                               1.4.1
# PyYAML                                   6.0.1
# pyzmq                                    24.0.1
# ray                                      2.8.0
# ray-cpp                                  2.8.0
# referencing                              0.30.2
# requests                                 2.31.0
# requests-oauthlib                        1.3.1
# requests-toolbelt                        0.10.1
# retrying                                 1.3.4
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.6.0
# rpds-py                                  0.12.0
# rsa                                      4.9
# ruamel.yaml                              0.18.5
# ruamel.yaml.clib                         0.2.7
# scikit-image                             0.22.0
# scikit-learn                             1.3.2
# scipy                                    1.11.3
# seaborn                                  0.12.2
# SecretStorage                            3.3.3
# Send2Trash                               1.8.2
# setuptools                               68.2.2
# shapely                                  2.0.2
# six                                      1.16.0
# smart-open                               6.4.0
# smmap                                    5.0.1
# sniffio                                  1.3.0
# soupsieve                                2.5
# SQLAlchemy                               2.0.23
# sqlparse                                 0.4.4
# stack-data                               0.6.2
# starlette                                0.27.0
# statsmodels                              0.14.0
# tabulate                                 0.9.0
# tangled-up-in-unicode                    0.2.0
# tenacity                                 8.2.3
# tensorboardX                             2.6.2.2
# terminado                                0.17.1
# threadpoolctl                            3.2.0
# tifffile                                 2023.9.26
# tinycss2                                 1.2.1
# tomli                                    2.0.1
# tornado                                  6.3.3
# tqdm                                     4.66.1
# traitlets                                5.13.0
# truststore                               0.8.0
# typeguard                                4.1.5
# typer                                    0.9.0
# types-python-dateutil                    2.8.19.14
# typing_extensions                        4.8.0
# typing-utils                             0.1.0
# tzdata                                   2023.3
# uri-template                             1.3.0
# uritemplate                              3.0.1
# urllib3                                  1.26.18
# uvicorn                                  0.24.0.post1
# uvloop                                   0.19.0
# virtualenv                               20.21.0
# visions                                  0.7.5
# watchfiles                               0.21.0
# wcwidth                                  0.2.9
# webcolors                                1.13
# webencodings                             0.5.1
# websocket-client                         1.6.4
# websockets                               12.0
# wheel                                    0.41.3
# widgetsnbextension                       4.0.9
# wordcloud                                1.9.2
# wrapt                                    1.15.0
# yarl                                     1.9.2
# ydata-profiling                          4.6.0
# zipp                                     3.17.0
# zstandard                                0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.25.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.11.3)
# Downloading xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 5.9 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
import pandas as pd
import xgboost

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    tree_id    legal_status     species address  site_order  \
# 0    30483  Permitted Site  Tree(s) ::    None           4
# 1    45997  Permitted Site  Tree(s) ::    None         115
# 2    48142  Permitted Site  Tree(s) ::    None         252
# 3    48199  Permitted Site  Tree(s) ::    None          58
# 4    48308  Permitted Site  Tree(s) ::    None         174
#
#                       site_info plant_type care_taker care_assistant  \
# 0  Sidewalk: Curb side : Cutout       Tree    Private           None
# 1  Sidewalk: Curb side : Cutout       Tree    Private           None
# 2  Sidewalk: Curb side : Cutout       Tree    Private           None
# 3  Sidewalk: Curb side : Cutout       Tree    Private           None
# 4  Sidewalk: Curb side : Cutout       Tree    Private           None
#
#                  plant_date   dbh plot_size         permit_notes  \
# 0 1956-09-05 12:00:00+00:00  None      None    Permit Number 147
# 1 2001-12-06 12:00:00+00:00  None      None  Permit Number 44451
# 2 2002-07-17 12:00:00+00:00  None      None  Permit Number 45761
# 3 2002-07-17 12:00:00+00:00  None      None  Permit Number 45761
# 4 2002-07-17 12:00:00+00:00  None      None  Permit Number 45761
#
#    x_coordinate  y_coordinate  latitude  longitude location
# 0           NaN           NaN       NaN        NaN     None
# 1           NaN           NaN       NaN        NaN     None
# 2           NaN           NaN       NaN        NaN     None
# 3           NaN           NaN       NaN        NaN     None
# 4           NaN           NaN       NaN        NaN     None

# %%
# %%bigquery df_tree
# SELECT species, count(*) as num_trees, min(plant_date) as min_plant_date, max(plant_date) as max_plant_date
# FROM `bigquery-public-data.san_francisco_trees.street_trees`
# GROUP BY species
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_tree
# Out:
#                                                species  num_trees  \
# 0                                           Tree(s) ::      11822
# 1           Arbutus 'Marina' :: Hybrid Strawberry Tree       5800
# 2                Lophostemon confertus :: Brisbane Box       9046
# 3        Metrosideros excelsa :: New Zealand Xmas Tree       8878
# 4    Ceanothus 'Ray Hartman' :: California Lilac 'R...        360
# ..                                                 ...        ...
# 577  Viburnum odoratissimum var. awabuki :: Sweet v...          6
# 578                 Yucca aloifolia :: Spanish bayonet          1
# 579                 Rhopalostylis sapida :: Nikau palm          1
# 580  Callistemon salignus :: White flowering bottle...          1
# 581                 Macadamia tetraphylla :: Macadamia          1
#
#                min_plant_date            max_plant_date
# 0   1955-09-19 12:00:00+00:00 2023-11-30 12:00:00+00:00
# 1   1956-02-06 12:00:00+00:00 2023-11-07 07:00:00+00:00
# 2   1969-07-28 12:00:00+00:00 2023-11-06 12:00:00+00:00
# 3   1956-06-14 12:00:00+00:00 2023-08-05 12:00:00+00:00
# 4   1969-12-18 12:00:00+00:00 2023-12-01 12:00:00+00:00
# ..                        ...                       ...
# 577                       NaT                       NaT
# 578                       NaT                       NaT
# 579                       NaT                       NaT
# 580                       NaT                       NaT
# 581                       NaT                       NaT
#
# [582 rows x 4 columns]
